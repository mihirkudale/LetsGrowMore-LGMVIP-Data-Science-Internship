# %% [markdown]
# # Data Science Intern @ LetsGrowMore
# # Author : Mihir Kudale
# # BEGINNER LEVEL TASK 04
# ## Image to Pencil Sketch with Python:

# %% [markdown]
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# ## Importing libraries

# %%
import cv2
from PIL import Image
from IPython.display import display

# %% [markdown]
# ## Reading the image

# %%
img = cv2.imread("test.jpg")
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=183x275 at 0x180CB317A30>

# %% [markdown]
# #### We can see thet the image appears to be bluish. This happens because the opencv reads the image in BGR format.

# %% [markdown]
# ## Original Image

# %%
orig_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(orig_img))
# Out:
# <PIL.Image.Image image mode=RGB size=183x275 at 0x180CBC867C0>

# %% [markdown]
# ## Converting original image to greyscale image

# %%
gray_img = cv2.cvtColor(orig_img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_img))
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x180CBC86550>

# %% [markdown]
# #### The above image looks like a black and white image

# %% [markdown]
# ## Inverting the new grayscale image

# %%
inverted_img = 255 - gray_img
display(Image.fromarray(inverted_img))
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x180CB3177C0>

# %% [markdown]
# #### The above image looks like a negative image.

# %% [markdown]
# ## Blurring the image using GaussianBlur function in OpenCv

# %%
blurred = cv2.GaussianBlur(inverted_img, (21,21), 0)
display(Image.fromarray(blurred))
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x180CB3177C0>

# %% [markdown]
# ## Converting blurred image into pencil sketch

# %%
inverted_blurred=255-blurred
pencil_sketch = cv2.divide(gray_img, inverted_blurred, scale=256.0)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x180CBAB3DF0>

# %% [markdown]
# ## Original image vs Sketch

# %%
display(Image.fromarray(orig_img))
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=183x275 at 0x180CBC86FA0>
# <PIL.Image.Image image mode=L size=183x275 at 0x180CBAB3D90>
